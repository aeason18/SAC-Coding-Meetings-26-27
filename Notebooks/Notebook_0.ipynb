# %%
import pandas as pd
from sqlalchemy import create_engine


USER = 'postgres'
PASSWORD = 'your_password_here'  
HOST = 'localhost'
PORT = '5432'
DATABASE = 'postgres'
TABLE_NAME = 'qb_data'

engine = create_engine(f'postgresql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}')
df = pd.DataFrame()
df = pd.read_sql_table(TABLE_NAME, con=engine)
df
# Out:
#       Rk            Player  Age Team Pos   G  GS   QBrec  Cmp  Att  ...  \
# 0      1  Matthew Stafford   37  LAR  QB  17  17  12-5-0  388  597  ...
# 1      2        Jared Goff   31  DET  QB  17  17   9-8-0  393  578  ...
# 2      3      Dak Prescott   32  DAL  QB  17  17   7-9-1  404  600  ...
# 3      4        Drake Maye   23  NWE  QB  17  17  14-3-0  354  492  ...
# 4      5       Sam Darnold   28  SEA  QB  17  17  14-3-0  323  477  ...
# ..   ...               ...  ...  ...  ..  ..  ..     ...  ...  ...  ...
# 199   96      Brett Rypien   29  CIN  QB   1   0            0    0  ...
# 200   97  Courtland Sutton   30  DEN  WR  17  16            0    0  ...
# 201   98      Tyler Warren   23  IND  TE  17  12            0    1  ...
# 202   99   Isaiah Williams   24  NYJ  WR  15   2            0    1  ...
# 203  100      Kedon Slovis   24  ARI  QB   2   0            1    2  ...
#
#       Rate   QBR  Sk  Sk_PCT  NY_A  ANY_A  4QC  GWD                   Awards  \
# 0    109.2  71.2  23    3.71  7.35    8.3  1.0  1.0           PBAP-1AP MVP-1
# 1    105.5  57.3  38    6.17  6.99    7.5  1.0  3.0                       PB
# 2     99.5  70.2  31    4.91  6.88    7.1  4.0  3.0              PBAP CPoY-3
# 3    113.5  77.1  47    8.72  7.78    8.3  1.0  2.0  PBAP-2AP MVP-2AP OPoY-5
# 4     99.1  55.6  27    5.36  7.66    7.4  2.0  4.0                       PB
# ..     ...   ...  ..     ...   ...    ...  ...  ...                      ...
# 199    NaN   0.0   1     NaN   NaN    NaN  NaN  NaN                      NaN
# 200    NaN   0.0   1     NaN   NaN    NaN  NaN  NaN                      NaN
# 201   39.6   0.0   0     NaN   NaN    NaN  NaN  NaN                      NaN
# 202   39.6   1.6   0     NaN   NaN    NaN  NaN  NaN                      NaN
# 203   56.2   0.3   0     NaN   NaN    NaN  NaN  NaN                      NaN
#
#      Player-additional
# 0             StafMa00
# 1             GoffJa00
# 2             PresDa01
# 3             MayeDr00
# 4             DarnSa00
# ..                 ...
# 199                NaN
# 200                NaN
# 201                NaN
# 202                NaN
# 203                NaN
#
# [204 rows x 33 columns]
